# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import csv

# %%
df = pd.read_csv("Train.csv")

# %%
f1 = np.asarray(list(df.get('feature_1')))

# %%
f2 = np.asarray(list(df.get('feature_2')))
f3 = np.asarray(list(df.get('feature_3')))
f4 = np.asarray(list(df.get('feature_4')))
f5 = np.asarray(list(df.get('feature_5')))
Y = np.asarray(list(df.get('target')))
print(Y)
# Out:
# [ -82.15466656  -48.89796018   77.2703707  ... -107.51050797  -47.34155781
#  -115.93900296]

# %%
def hypothesis(theta,f1,f2,f3,f4,f5):
    return theta[0]+theta[1]*f1+theta[2]*f2+theta[3]*f3+theta[4]*f4+theta[5]*f5

# %%
def gradient(theta,f1,f2,f3,f4,f5,Y):
    grad = np.zeros((6))
    m = Y.shape[0]
    
    for i in range(m):
        hx = hypothesis(theta,f1[i],f2[i],f3[i],f4[i],f5[i])
        grad[0]+= (hx-Y[i])
        grad[1]+= (hx-Y[i])*f1[i]
        grad[2]+= (hx-Y[i])*f2[i]
        grad[3]+= (hx-Y[i])*f3[i]
        grad[4]+= (hx-Y[i])*f4[i]
        grad[5]+= (hx-Y[i])*f5[i]
    return grad

# %%
def gradient_descent(theta,f1,f2,f3,f4,f5,Y,lr=0.000001,max_itr = 300):
    grad = gradient(theta,f1,f2,f3,f4,f5,Y)
    for i in range (max_itr):
        theta[0] = theta[0]+lr*grad[0]
        theta[1] = theta[1]+lr*grad[1]
        theta[2] = theta[2]+lr*grad[2]
        theta[3] = theta[3]+lr*grad[3]
        theta[4] = theta[4]+lr*grad[4]
        theta[5] = theta[5]+lr*grad[5]
    return theta

# %%
theta = np.zeros((6))

# %%
theta = gradient_descent(theta,f1,f2,f3,f4,f5,Y,lr=0.000001,max_itr = 5)

# %%
y = list()
for i in range(400):
    a =  hypothesis(theta,f1[i],f2[i],f3[i],f4[i],f5[i])
    y.append(a)
print(y)
# Out:
# [15.57154256137563, 21.650549913287005, -12.113311689618506, -2.4184299890460155, 7.734698442630796, 34.99067968789071, -4.1044831587921085, 7.234438216546099, -2.8237197231862896, 21.915942786393277, 11.476498875786223, -17.331820722595076, 22.19424109693141, 32.1774792349912, 40.0940401346017, -9.58791341355584, 20.78762625260787, 10.80551794439935, -13.983718455923137, -17.27252564030135, 13.386339919149322, -56.27890813923175, 39.91745702675928, 37.401483216566895, -48.12484770657353, -39.88707987043618, 2.967166463594026, 6.700628201833084, 20.258670892537044, -55.158245916700196, 40.61714433836578, 34.60965048841852, -7.79215224580193, 9.6073558676391, 33.308211926091936, -22.237346471542185, 23.792366401252576, -48.07489965835862, -12.264574683155466, 31.73819805706878, 24.84462014158021, 41.44787118560853, -1.7721632965835674, 29.17385235793223, 50.71592821682039, 28.804620217450964, 82.97795011146589, -1.7411989033322004, -0.6254889402954409, -33.70536812675655, 14.273163943170196, 16.717809619541235, 19.804